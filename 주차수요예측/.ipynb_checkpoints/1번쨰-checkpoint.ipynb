# %%
import pandas as pd
import matplotlib 
import matplotlib.pyplot as plt
matplotlib.font_manager._rebuild()

plt.rc("font", family="Malgun Gothic")

# %%
train = pd.read_csv('Parking_data/train.csv')
test = pd.read_csv('Parking_data/test.csv')
submission = pd.read_csv('Parking_data/sample_submission.csv')
age_gender = pd.read_csv('Parking_data/age_gender_info.csv')

# %%
print('train.shape :' ,train.shape)
train.sort_values('단지코드')
# Out:
# train.shape : (2952, 15)
#        단지코드  총세대수 임대건물구분    지역  공급유형   전용면적  전용면적별세대수   공가수 자격유형     임대보증금  \
# 1805  C1000   566    아파트  충청북도  국민임대  39.93        75  10.0    A  10803000
# 1803  C1000   566    아파트  충청북도  국민임대  39.57       318  10.0    A  10803000
# 1806  C1000   566    아파트  충청북도  국민임대  46.70        36  10.0    A  14404000
# 1807  C1000   566    아파트  충청북도  국민임대  46.90        36  10.0    A  14404000
# 1808  C1000   566    아파트  충청북도  국민임대  51.93        60  10.0    A  15604000
# ...     ...   ...    ...   ...   ...    ...       ...   ...  ...       ...
# 1963  C2692   499    아파트  경상북도  국민임대  36.64       277  19.0    A  10242000
# 1965  C2692   499    아파트  경상북도  국민임대  46.49        60  19.0    A  18173000
# 1966  C2692   499    아파트  경상북도  국민임대  46.49        45  19.0    A  18173000
# 1967  C2692   499    아파트  경상북도  국민임대  51.59        60  19.0    A  22138000
# 1964  C2692   499    아파트  경상북도  국민임대  36.64        57  19.0    A  10242000
#
#          임대료  도보 10분거리 내 지하철역 수(환승노선 수 반영)  도보 10분거리 내 버스정류장 수  단지내주차면수  등록차량수
# 1805   96030                           0.0                 1.0    438.0  481.0
# 1803   96030                           0.0                 1.0    438.0  481.0
# 1806  129640                           0.0                 1.0    438.0  481.0
# 1807  129640                           0.0                 1.0    438.0  481.0
# 1808  150040                           0.0                 1.0    438.0  481.0
# ...      ...                           ...                 ...      ...    ...
# 1963   82600                           0.0                 2.0    409.0  437.0
# 1965  132170                           0.0                 2.0    409.0  437.0
# 1966  132170                           0.0                 2.0    409.0  437.0
# 1967  159700                           0.0                 2.0    409.0  437.0
# 1964   82600                           0.0                 2.0    409.0  437.0
#
# [2952 rows x 15 columns]

# %%
print('test.shape:',test.shape)
test.sort_values('단지코드')
# Out:
# test.shape: (1022, 14)
#       단지코드  총세대수 임대건물구분    지역       공급유형   전용면적  전용면적별세대수   공가수 자격유형  \
# 855  C1003   480    아파트  경상남도       행복주택  26.34       172  29.0    J
# 861  C1003   480    아파트  경상남도       행복주택  44.29         6  29.0    J
# 860  C1003   480    아파트  경상남도       행복주택  44.16        28  29.0    J
# 859  C1003   480    아파트  경상남도       행복주택  36.44        12  29.0    J
# 858  C1003   480    아파트  경상남도       행복주택  36.31        56  29.0    J
# ..     ...   ...    ...   ...        ...    ...       ...   ...  ...
# 882  C2688   150    아파트  전라남도       국민임대  46.53        16   1.0    H
# 883  C2688   150    아파트  전라남도       영구임대  24.59        26   1.0    C
# 785  C2691   765    아파트   경기도  공공임대(10년)  74.95       150  25.0    A
# 784  C2691   765    아파트   경기도  공공임대(10년)  74.89        25  25.0    A
# 786  C2691   765    아파트   경기도  공공임대(10년)  84.84       590  25.0    A
#
#         임대보증금     임대료  도보 10분거리 내 지하철역 수(환승노선 수 반영)  도보 10분거리 내 버스정류장 수  \
# 855  19600000  100000                           0.0                 3.0
# 861  30000000  154000                           0.0                 3.0
# 860  30000000  154000                           0.0                 3.0
# 859  25600000  131000                           0.0                 3.0
# 858  25600000  131000                           0.0                 3.0
# ..        ...     ...                           ...                 ...
# 882  16448000  194290                           0.0                 3.0
# 883   9113000   86450                           0.0                 3.0
# 785  66000000  550000                           0.0                19.0
# 784  66000000  550000                           0.0                19.0
# 786  80000000  580000                           0.0                19.0
#
#      단지내주차면수
# 855    339.0
# 861    339.0
# 860    339.0
# 859    339.0
# 858    339.0
# ..       ...
# 882    107.0
# 883    107.0
# 785    910.0
# 784    910.0
# 786    910.0
#
# [1022 rows x 14 columns]

# %%
submission
# Out:
#       code  num
# 0    C1072    0
# 1    C1128    0
# 2    C1456    0
# 3    C1840    0
# 4    C1332    0
# ..     ...  ...
# 145  C2456    0
# 146  C1266    0
# 147  C2152    0
# 148  C1267    0
# 149  C2189    0
#
# [150 rows x 2 columns]

# %%
train.groupby('단지코드').mean()
# Out:
#          총세대수       전용면적    전용면적별세대수   공가수  도보 10분거리 내 지하철역 수(환승노선 수 반영)  \
# 단지코드
# C1000   566.0  45.218571   80.857143  10.0                           0.0
# C1004   521.0  39.136842   27.421053   3.0                           NaN
# C1005  1144.0  54.360000  381.333333  16.0                           NaN
# C1013  1308.0  46.142000  261.600000  16.0                           0.0
# C1014   996.0  49.232857  142.285714   5.0                           0.0
# ...       ...        ...         ...   ...                           ...
# C2663   772.0  41.005000  128.666667  14.0                           0.0
# C2666  1084.0  43.258333  180.666667  23.0                           0.0
# C2670   648.0  40.918000  129.600000   9.0                           0.0
# C2680   758.0  43.350000  252.666667  19.0                           0.0
# C2692   499.0  43.570000   99.800000  19.0                           0.0
#
#        도보 10분거리 내 버스정류장 수  단지내주차면수   등록차량수
# 단지코드
# C1000                 1.0    438.0   481.0
# C1004                 2.0    153.0    93.0
# C1005                 8.0    950.0   376.0
# C1013                 6.0   1119.0  1665.0
# C1014                 2.0    823.0   708.0
# ...                   ...      ...     ...
# C2663                 3.0    700.0   652.0
# C2666                 1.0    837.0   701.0
# C2670                 2.0    600.0   435.0
# C2680                 7.0    564.0   590.0
# C2692                 2.0    409.0   437.0
#
# [423 rows x 8 columns]

# %%
train.info() #
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2952 entries, 0 to 2951
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   단지코드                          2952 non-null   object
#  1   총세대수                          2952 non-null   int64
#  2   임대건물구분                        2952 non-null   object
#  3   지역                            2952 non-null   object
#  4   공급유형                          2952 non-null   object
#  5   전용면적                          2952 non-null   float64
#  6   전용면적별세대수                      2952 non-null   int64
#  7   공가수                           2952 non-null   float64
#  8   자격유형                          2952 non-null   object
#  9   임대보증금                         2383 non-null   object
#  10  임대료                           2383 non-null   object
#  11  도보 10분거리 내 지하철역 수(환승노선 수 반영)  2741 non-null   float64
#  12  도보 10분거리 내 버스정류장 수            2948 non-null   float64
#  13  단지내주차면수                       2952 non-null   float64
#  14  등록차량수                         2952 non-null   float64
# dtypes: float64(6), int64(2), object(7)
# memory usage: 346.1+ KB

# %%
# 상가 --> 0 으로 아파트 ---> 1
# 임대보증금 ---> int로 ---> -가 있어서 안된다함  ---> -을 비워주기 ---> 적용시키기
# 임대료 ---> int로 ---> -가 있어서 안된다함  ---> -을 비워주기 ---> 적용시키기
train['임대건물구분'] = train['임대건물구분'].map({'상가':0 , '아파트':1})

# %%
train[train['임대보증금'] == '-'] = train[train['임대보증금'] == '-'].replace('-','')

# %%
train['임대보증금'] = train['임대보증금'].apply(pd.to_numeric)

# %%
train[train['임대료'] == '-'] = train[train['임대료'] == '-'].replace('-','' )

# %%
train['임대료'] = train['임대료'].apply(pd.to_numeric)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2952 entries, 0 to 2951
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   단지코드                          2952 non-null   object
#  1   총세대수                          2952 non-null   int64
#  2   임대건물구분                        2952 non-null   int64
#  3   지역                            2952 non-null   object
#  4   공급유형                          2952 non-null   object
#  5   전용면적                          2952 non-null   float64
#  6   전용면적별세대수                      2952 non-null   int64
#  7   공가수                           2952 non-null   float64
#  8   자격유형                          2952 non-null   object
#  9   임대보증금                         2371 non-null   float64
#  10  임대료                           2362 non-null   float64
#  11  도보 10분거리 내 지하철역 수(환승노선 수 반영)  2741 non-null   float64
#  12  도보 10분거리 내 버스정류장 수            2948 non-null   float64
#  13  단지내주차면수                       2952 non-null   float64
#  14  등록차량수                         2952 non-null   float64
# dtypes: float64(8), int64(3), object(4)
# memory usage: 346.1+ KB

# %%
train = train.groupby('단지코드').mean()

# %%
train.isna().sum()
# Out:
# 총세대수                             0
# 임대건물구분                           0
# 전용면적                             0
# 전용면적별세대수                         0
# 공가수                              0
# 임대보증금                            1
# 임대료                              2
# 도보 10분거리 내 지하철역 수(환승노선 수 반영)    20
# 도보 10분거리 내 버스정류장 수               1
# 단지내주차면수                          0
# 등록차량수                            0
# dtype: int64

# %%
train = train.dropna(axis = 0)

# %%
train.isna().sum()
# Out:
# 총세대수                            0
# 임대건물구분                          0
# 전용면적                            0
# 전용면적별세대수                        0
# 공가수                             0
# 임대보증금                           0
# 임대료                             0
# 도보 10분거리 내 지하철역 수(환승노선 수 반영)    0
# 도보 10분거리 내 버스정류장 수              0
# 단지내주차면수                         0
# 등록차량수                           0
# dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 401 entries, C1000 to C2692
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   총세대수                          401 non-null    float64
#  1   임대건물구분                        401 non-null    float64
#  2   전용면적                          401 non-null    float64
#  3   전용면적별세대수                      401 non-null    float64
#  4   공가수                           401 non-null    float64
#  5   임대보증금                         401 non-null    float64
#  6   임대료                           401 non-null    float64
#  7   도보 10분거리 내 지하철역 수(환승노선 수 반영)  401 non-null    float64
#  8   도보 10분거리 내 버스정류장 수            401 non-null    float64
#  9   단지내주차면수                       401 non-null    float64
#  10  등록차량수                         401 non-null    float64
# dtypes: float64(11)
# memory usage: 37.6+ KB

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,10))
sns.heatmap(train.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
train[train['임대건물구분'] <1]
# Out:
#          총세대수    임대건물구분       전용면적    전용면적별세대수   공가수         임대보증금  \
# 단지코드
# C1056   410.0  0.166667  31.268333   34.166667   0.0  3.384500e+06
# C1109  1957.0  0.090909  45.409545   88.954545   1.0  6.330000e+06
# C1206   755.0  0.166667  42.798333   40.666667   1.0  3.436000e+06
# C1439  1755.0  0.062500  42.334375   36.562500  29.0  7.169333e+06
# C1476   453.0  0.250000  36.293750   56.625000   6.0  8.697000e+06
# C1698   460.0  0.500000  35.647500   57.500000   1.0  1.286400e+07
# C1722   809.0  0.454545  38.854545   73.545455   1.0  1.056040e+07
# C1775   711.0  0.117647  37.651176   41.823529   5.0  4.344500e+06
